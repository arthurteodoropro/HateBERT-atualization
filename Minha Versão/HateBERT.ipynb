# %%
# ========================================
# BAIXAR DIRETO DO OSF PARA O COLAB
# ========================================

# %cd /content

print("📥 Baixando projeto HateBERT do OSF...")
# !pip install -q osfclient

print("\n📂 Clonando projeto tbd58 do OSF...")
# !osf -p tbd58 clone HateBERT_Project

print("\n✅ Download concluído!")

print("\n📋 Estrutura baixada:")
# !ls -lah HateBERT_Project/

print("\n📂 Conteúdo de osfstorage:")
# !ls -lah HateBERT_Project/osfstorage/

print("\n📂 Software:")
# !ls -lah HateBERT_Project/osfstorage/software/

print("\n✅ Pronto para treinar!")
# Out:
# /content
# 📥 Baixando projeto HateBERT do OSF...
#
# 📂 Clonando projeto tbd58 do OSF...
# 0files [00:00, ?files/s]
#   0% 0.00/406M [00:00<?, ?bytes/s]
#   0% 49.2k/406M [00:00<24:49, 272kbytes/s]
#   0% 81.9k/406M [00:00<28:47, 235kbytes/s]
#   0% 164k/406M [00:00<17:09, 394kbytes/s]
#   0% 262k/406M [00:00<12:17, 550kbytes/s]
#   0% 426k/406M [00:00<07:52, 858kbytes/s]
#   0% 639k/406M [00:00<05:29, 1.23Mbytes/s]
#   0% 1.02M/406M [00:00<03:25, 1.97Mbytes/s]
#   0% 1.59M/406M [00:00<02:11, 3.08Mbytes/s]
#   1% 2.54M/406M [00:01<01:21, 4.96Mbytes/s]
#   1% 4.05M/406M [00:01<00:50, 7.95Mbytes/s]
#   2% 6.42M/406M [00:01<00:31, 12.6Mbytes/s]
#   2% 9.14M/406M [00:01<00:23, 16.9Mbytes/s]
#   3% 11.9M/406M [00:01<00:19, 20.0Mbytes/s]
#   4% 14.4M/406M [00:01<00:18, 21.7Mbytes/s]
#   4% 17.0M/406M [00:01<00:16, 22.9Mbytes/s]
#   5% 20.0M/406M [00:01<00:15, 24.2Mbytes/s]
#   6% 23.0M/406M [00:01<00:14, 25.6Mbytes/s]
#   6% 25.5M/406M [00:02<00:15, 25.2Mbytes/s]
#   7% 28.3M/406M [00:02<00:14, 26.0Mbytes/s]
#   8% 31.1M/406M [00:02<00:14, 26.2Mbytes/s]
#   8% 33.7M/406M [00:02<00:14, 26.1Mbytes/s]
#   9% 36.3M/406M [00:02<00:14, 26.1Mbytes/s]
#  10% 39.1M/406M [00:02<00:13, 26.2Mbytes/s]
#  10% 42.1M/406M [00:02<00:13, 26.9Mbytes/s]
#  11% 44.8M/406M [00:02<00:13, 26.3Mbytes/s]
#  12% 47.6M/406M [00:02<00:13, 25.9Mbytes/s]
#  12% 50.6M/406M [00:02<00:13, 26.4Mbytes/s]
#  13% 53.4M/406M [00:03<00:13, 26.9Mbytes/s]
#  14% 56.1M/406M [00:03<00:13, 26.5Mbytes/s]
#  14% 58.8M/406M [00:03<00:13, 25.6Mbytes/s]
#  15% 61.7M/406M [00:03<00:13, 25.7Mbytes/s]
#  16% 64.2M/406M [00:03<00:13, 25.5Mbytes/s]
#  16% 66.8M/406M [00:03<00:13, 25.5Mbytes/s]
#  17% 69.7M/406M [00:03<00:13, 25.8Mbytes/s]
#  17% 14.5M/84.8M [00:01<00:03, 21.6Mbytes/s]
#  20% 17.0M/84.8M [00:01<00:02, 22.7Mbytes/s]
#  24% 20.0M/84.8M [00:01<00:02, 24.0Mbytes/s]
#  27% 22.8M/84.8M [00:01<00:02, 25.3Mbytes/s]
#  30% 25.5M/84.8M [00:02<00:02, 25.6Mbytes/s]
#  33% 28.1M/84.8M [00:02<00:02, 25.1Mbytes/s]
#  37% 31.0M/84.8M [00:02<00:02, 26.0Mbytes/s]
#  40% 33.6M/84.8M [00:02<00:01, 26.0Mbytes/s]
#  43% 36.2M/84.8M [00:02<00:01, 25.8Mbytes/s]
#  46% 39.1M/84.8M [00:02<00:01, 25.9Mbytes/s]
#  50% 42.0M/84.8M [00:02<00:01, 26.8Mbytes/s]
#  53% 44.7M/84.8M [00:02<00:01, 26.1Mbytes/s]
#  56% 47.3M/84.8M [00:02<00:01, 26.1Mbytes/s]
#  59% 49.9M/84.8M [00:03<00:01, 18.2Mbytes/s]
#  64% 54.0M/84.8M [00:03<00:01, 21.3Mbytes/s]
#  68% 57.8M/84.8M [00:03<00:01, 22.8Mbytes/s]
#  73% 61.6M/84.8M [00:03<00:00, 23.8Mbytes/s]
#  77% 65.5M/84.8M [00:03<00:00, 24.6Mbytes/s]
#  82% 69.3M/84.8M [00:03<00:00, 25.1Mbytes/s]
#  86% 73.1M/84.8M [00:03<00:00, 25.5Mbytes/s]
#  91% 76.9M/84.8M [00:04<00:00, 25.7Mbytes/s]
#  95% 80.8M/84.8M [00:04<00:00, 25.9Mbytes/s]
# 100% 84.8M/84.8M [00:04<00:00, 19.2Mbytes/s]
# 5files [01:23, 11.55s/files]
# 100% 10.9k/10.9k [00:00<00:00, 40.6Mbytes/s]
# 6files [01:25,  8.32s/files]
# 100% 7.20k/7.20k [00:00<00:00, 32.6Mbytes/s]
# 7files [01:26,  5.94s/files]
# 100% 34.3k/34.3k [00:00<00:00, 1.65Mbytes/s]
# 8files [01:27,  4.38s/files]
# 100% 25.8k/25.8k [00:00<00:00, 2.57Mbytes/s]
# 9files [01:29,  3.66s/files]
# 100% 25.6k/25.6k [00:00<00:00, 2.57Mbytes/s]
# 10files [01:31,  3.10s/files]
# 100% 25.6k/25.6k [00:00<00:00, 2.45Mbytes/s]
# 11files [01:32,  2.48s/files]
# 100% 25.4k/25.4k [00:00<00:00, 2.56Mbytes/s]
# 12files [01:33,  2.05s/files]
# 100% 464/464 [00:00<00:00, 3.11Mbytes/s]
# 13files [01:34,  1.74s/files]
# 100% 10.8k/10.8k [00:00<00:00, 29.2Mbytes/s]
# 14files [01:35,  1.52s/files]
#   0% 0.00/809M [00:00<?, ?bytes/s]
#   0% 49.2k/809M [00:00<49:19, 273kbytes/s]
#   0% 81.9k/809M [00:00<57:11, 236kbytes/s]
#   0% 164k/809M [00:00<34:13, 394kbytes/s]
#   0% 262k/809M [00:00<24:23, 553kbytes/s]
#   0% 426k/809M [00:00<15:44, 857kbytes/s]
#   0% 639k/809M [00:00<11:00, 1.22Mbytes/s]
#  82% 666M/809M [00:27<00:05, 26.4Mbytes/s]
#  83% 670M/809M [00:27<00:05, 26.5Mbytes/s]
#  83% 673M/809M [00:27<00:05, 23.4Mbytes/s]
#  83% 676M/809M [00:27<00:05, 22.8Mbytes/s]
#  84% 678M/809M [00:27<00:06, 21.1Mbytes/s]
#  84% 681M/809M [00:28<00:05, 22.1Mbytes/s]
#  85% 685M/809M [00:28<00:05, 23.4Mbytes/s]
#  85% 689M/809M [00:28<00:04, 24.4Mbytes/s]
#  86% 693M/809M [00:28<00:04, 25.0Mbytes/s]
#  86% 697M/809M [00:28<00:04, 25.5Mbytes/s]
#  87% 700M/809M [00:28<00:04, 25.8Mbytes/s]
#  87% 704M/809M [00:28<00:04, 26.0Mbytes/s]
#  87% 708M/809M [00:29<00:03, 26.2Mbytes/s]
#  88% 712M/809M [00:29<00:03, 26.2Mbytes/s]
#  88% 716M/809M [00:29<00:03, 26.3Mbytes/s]
#  89% 720M/809M [00:29<00:03, 26.4Mbytes/s]
#  89% 723M/809M [00:29<00:03, 26.4Mbytes/s]
#  90% 727M/809M [00:29<00:03, 26.5Mbytes/s]
#  90% 730M/809M [00:30<00:03, 22.4Mbytes/s]
#  91% 733M/809M [00:30<00:03, 22.6Mbytes/s]
#  91% 737M/809M [00:30<00:03, 23.8Mbytes/s]
#  92% 741M/809M [00:30<00:02, 24.6Mbytes/s]
#  92% 745M/809M [00:30<00:02, 25.2Mbytes/s]
#  92% 748M/809M [00:30<00:02, 25.6Mbytes/s]
#  93% 752M/809M [00:30<00:02, 25.9Mbytes/s]
#  93% 756M/809M [00:31<00:02, 26.1Mbytes/s]
#  94% 760M/809M [00:31<00:01, 26.3Mbytes/s]
#  94% 764M/809M [00:31<00:01, 26.3Mbytes/s]
#  95% 768M/809M [00:31<00:01, 26.4Mbytes/s]
#  95% 771M/809M [00:31<00:01, 26.4Mbytes/s]
#  96% 775M/809M [00:31<00:01, 26.4Mbytes/s]
#  96% 779M/809M [00:31<00:01, 26.5Mbytes/s]
#  97% 783M/809M [00:32<00:00, 26.5Mbytes/s]
#  97% 787M/809M [00:32<00:00, 26.5Mbytes/s]
#  98% 791M/809M [00:32<00:00, 26.5Mbytes/s]
#  98% 794M/809M [00:32<00:00, 26.5Mbytes/s]
#  99% 798M/809M [00:32<00:00, 26.5Mbytes/s]
#  99% 802M/809M [00:32<00:00, 26.5Mbytes/s]
# 100% 809M/809M [00:32<00:00, 24.5Mbytes/s]
# 15files [02:11, 11.88s/files]
#   0% 0.00/405M [00:00<?, ?bytes/s]
#   0% 49.2k/405M [00:00<25:39, 263kbytes/s]
#   0% 81.9k/405M [00:00<29:47, 226kbytes/s]
#   0% 164k/405M [00:00<17:48, 378kbytes/s]
#   0% 262k/405M [00:00<12:41, 531kbytes/s]
#   0% 410k/405M [00:00<08:27, 796kbytes/s]
#   0% 606k/405M [00:00<05:57, 1.13Mbytes/s]
#   0% 934k/405M [00:00<03:49, 1.76Mbytes/s]
#   0% 1.44M/405M [00:01<02:27, 2.73Mbytes/s]
#  65% 263M/405M [00:11<00:05, 24.4Mbytes/s]
#  66% 267M/405M [00:11<00:05, 24.8Mbytes/s]
#  67% 270M/405M [00:11<00:05, 25.0Mbytes/s]
#  68% 274M/405M [00:11<00:05, 25.1Mbytes/s]
#  69% 278M/405M [00:11<00:05, 25.2Mbytes/s]
#  70% 282M/405M [00:12<00:04, 25.3Mbytes/s]
#  71% 286M/405M [00:12<00:04, 25.3Mbytes/s]
#  72% 290M/405M [00:12<00:04, 24.1Mbytes/s]
#  72% 293M/405M [00:12<00:04, 23.7Mbytes/s]
#  73% 296M/405M [00:12<00:05, 21.8Mbytes/s]
#  74% 298M/405M [00:12<00:05, 19.6Mbytes/s]
#  74% 300M/405M [00:13<00:05, 17.8Mbytes/s]
#  75% 304M/405M [00:13<00:05, 20.2Mbytes/s]
#  76% 307M/405M [00:13<00:04, 21.7Mbytes/s]
#  77% 311M/405M [00:13<00:04, 22.9Mbytes/s]
#  78% 315M/405M [00:13<00:03, 23.6Mbytes/s]
#  79% 319M/405M [00:13<00:03, 24.2Mbytes/s]
#  80% 323M/405M [00:13<00:03, 24.5Mbytes/s]
#  81% 327M/405M [00:14<00:03, 24.8Mbytes/s]
#  82% 330M/405M [00:14<00:02, 25.0Mbytes/s]
#  83% 334M/405M [00:14<00:02, 25.1Mbytes/s]
#  84% 338M/405M [00:14<00:02, 25.2Mbytes/s]
#  84% 342M/405M [00:14<00:02, 25.3Mbytes/s]
#  85% 346M/405M [00:14<00:02, 25.3Mbytes/s]
#  86% 349M/405M [00:15<00:02, 25.3Mbytes/s]
#  87% 353M/405M [00:15<00:02, 25.4Mbytes/s]
#  88% 357M/405M [00:15<00:01, 25.4Mbytes/s]
#  89% 361M/405M [00:15<00:01, 25.5Mbytes/s]
#  90% 365M/405M [00:15<00:01, 25.4Mbytes/s]
#  91% 369M/405M [00:15<00:01, 25.4Mbytes/s]
#  92% 372M/405M [00:15<00:01, 25.5Mbytes/s]
#  93% 376M/405M [00:16<00:01, 25.5Mbytes/s]
#  94% 380M/405M [00:16<00:00, 25.5Mbytes/s]
#  95% 384M/405M [00:16<00:00, 25.5Mbytes/s]
#  96% 388M/405M [00:16<00:00, 25.4Mbytes/s]
#  97% 391M/405M [00:16<00:00, 25.4Mbytes/s]
#  98% 395M/405M [00:16<00:00, 25.4Mbytes/s]
#  99% 399M/405M [00:16<00:00, 25.4Mbytes/s]
# 100% 405M/405M [00:17<00:00, 23.6Mbytes/s]
# 16files [02:30, 13.79s/files]
#   0% 0.00/405M [00:00<?, ?bytes/s]
#   0% 49.2k/405M [00:00<24:52, 271kbytes/s]
#   0% 81.9k/405M [00:00<28:57, 233kbytes/s]
#   0% 164k/405M [00:00<17:15, 390kbytes/s]
#   0% 262k/405M [00:00<12:18, 548kbytes/s]
#   0% 426k/405M [00:00<07:56, 848kbytes/s]
#   0% 639k/405M [00:00<05:32, 1.21Mbytes/s]
#   0% 1.02M/405M [00:00<03:27, 1.94Mbytes/s]
#   0% 1.59M/405M [00:00<02:12, 3.03Mbytes/s]
#  84% 340M/405M [00:14<00:02, 26.2Mbytes/s]
#  85% 344M/405M [00:14<00:02, 26.2Mbytes/s]
#  86% 348M/405M [00:14<00:02, 26.2Mbytes/s]
#  87% 352M/405M [00:15<00:02, 26.2Mbytes/s]
#  88% 355M/405M [00:15<00:02, 24.4Mbytes/s]
#  89% 359M/405M [00:15<00:01, 24.2Mbytes/s]
#  89% 362M/405M [00:15<00:01, 23.0Mbytes/s]
#  90% 364M/405M [00:15<00:02, 20.1Mbytes/s]
#  91% 366M/405M [00:15<00:01, 19.3Mbytes/s]
#  91% 370M/405M [00:15<00:01, 21.4Mbytes/s]
#  92% 374M/405M [00:16<00:01, 22.8Mbytes/s]
#  93% 378M/405M [00:16<00:01, 23.8Mbytes/s]
#  94% 382M/405M [00:16<00:00, 24.6Mbytes/s]
#  95% 385M/405M [00:16<00:00, 25.0Mbytes/s]
#  96% 389M/405M [00:16<00:00, 25.4Mbytes/s]
#  97% 393M/405M [00:16<00:00, 25.7Mbytes/s]
#  98% 397M/405M [00:17<00:00, 25.8Mbytes/s]
#  99% 401M/405M [00:17<00:00, 25.9Mbytes/s]
# 100% 405M/405M [00:17<00:00, 23.4Mbytes/s]
# 17files [02:48,  9.91s/files]
# Traceback (most recent call last):
#   File "/usr/local/bin/osf", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/osfclient/__main__.py", line 120, in main
#     exit_code = args.func(args)
#                 ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/osfclient/cli.py", line 98, in wrapper
#     return_value = f(cli_args)
#                    ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/osfclient/cli.py", line 164, in clone
#     for store in project.storages:
#                  ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/osfclient/models/project.py", line 48, in storages
#     yield Storage(store, self.session)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/osfclient/models/core.py", line 14, in __init__
#     self._update_attributes(json)
#   File "/usr/local/lib/python3.12/dist-packages/osfclient/models/storage.py", line 33, in _update_attributes
#     self.name = self._get_attribute(storage, 'attributes', 'name')
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/osfclient/models/core.py", line 42, in _get_attribute
#     value = value[key]
#             ~~~~~^^^^^
# KeyError: 'name'
#
# ✅ Download concluído!
#
# 📋 Estrutura baixada:
# total 12K
# drwxr-xr-x 3 root root 4.0K Dec  2 22:01 .
# drwxr-xr-x 1 root root 4.0K Dec  2 22:01 ..
# drwxr-xr-x 6 root root 4.0K Dec  2 22:03 osfstorage
#
# 📂 Conteúdo de osfstorage:
# total 28K
# drwxr-xr-x 6 root root 4.0K Dec  2 22:03 .
# drwxr-xr-x 3 root root 4.0K Dec  2 22:01 ..
# drwxr-xr-x 2 root root 4.0K Dec  2 22:02 BERT_fine_tuned_models
# drwxr-xr-x 2 root root 4.0K Dec  2 22:03 HateBERT_fine_tuned_models
# -rw-r--r-- 1 root root 1.1K Dec  2 22:02 README
# drwxr-xr-x 2 root root 4.0K Dec  2 22:02 retraining_data
# drwxr-xr-x 3 root root 4.0K Dec  2 22:03 software
#
# 📂 Software:
# total 84K
# drwxr-xr-x 3 root root 4.0K Dec  2 22:03 .
# drwxr-xr-x 6 root root 4.0K Dec  2 22:03 ..
# drwxr-xr-x 2 root root 4.0K Dec  2 22:03 fine_tuning_script
# -rw-r--r-- 1 root root  464 Dec  2 22:03 pre_train_command.sh
# -rw-r--r-- 1 root root 7.1K Dec  2 22:02 requirements.txt
# -rw-r--r-- 1 root root  34K Dec  2 22:02 run_language_modeling.py
# -rw-r--r-- 1 root root  11K Dec  2 22:02 text_classification_with_pretrained_model_offenseval.py
# -rw-r--r-- 1 root root  11K Dec  2 22:03 text_classification_with_pretrained_model.py
#
# ✅ Pronto para treinar!

# %%
# ========================================
# TREINAR COM 5 ÉPOCAS + GRÁFICOS DE APRENDIZAGEM
# ========================================

# %cd /content/HateBERT_Project/osfstorage

print("📦 Instalando dependências...")
# !pip install -q transformers datasets torch scikit-learn pandas numpy tqdm matplotlib seaborn

print("\n⚙️ Criando script de treinamento com 5 épocas e gráficos...")

with open('train_5epochs_graphs.py', 'w') as f:
    f.write('import torch\n')
    f.write('from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer\n')
    f.write('from datasets import load_dataset\n')
    f.write('import numpy as np\n')
    f.write('from sklearn.metrics import accuracy_score, precision_recall_fscore_support, f1_score, confusion_matrix\n')
    f.write('import matplotlib.pyplot as plt\n')
    f.write('import seaborn as sns\n')
    f.write('import json\n')
    f.write('import os\n\n')

    f.write('print("🔧 Configurando treinamento HateBERT com 5 épocas...")\n\n')

    f.write('MODEL_NAME = "GroNLP/hateBERT"\n')
    f.write('OUTPUT_DIR = "./hatebert_5epochs"\n')
    f.write('NUM_EPOCHS = 5\n')
    f.write('BATCH_SIZE = 16\n\n')

    f.write('device = "cuda" if torch.cuda.is_available() else "cpu"\n')
    f.write('print(f"💻 Usando: {device}")\n\n')

    f.write('print("\\n📥 Carregando HateBERT...")\n')
    f.write('tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)\n')
    f.write('model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=2)\n\n')

    f.write('print("\\n📊 Carregando dataset de hate speech (tweet_eval)...")\n')
    f.write('dataset = load_dataset("tweet_eval", "hate")\n\n')

    f.write('print(f"Dados de treino: {len(dataset[\'train\'])} exemplos")\n')
    f.write('print(f"Dados de validação: {len(dataset[\'validation\'])} exemplos")\n')
    f.write('print(f"Dados de teste: {len(dataset[\'test\'])} exemplos")\n\n')

    f.write('def tokenize_function(examples):\n')
    f.write('    return tokenizer(examples["text"], padding="max_length", truncation=True, max_length=128)\n\n')

    f.write('print("\\n🔄 Tokenizando dados...")\n')
    f.write('tokenized_datasets = dataset.map(tokenize_function, batched=True)\n\n')

    f.write('def compute_metrics(eval_pred):\n')
    f.write('    logits, labels = eval_pred\n')
    f.write('    predictions = np.argmax(logits, axis=-1)\n')
    f.write('    acc = accuracy_score(labels, predictions)\n')
    f.write('    precision, recall, f1, _ = precision_recall_fscore_support(labels, predictions, average="binary")\n')
    f.write('    return {\n')
    f.write('        "accuracy": acc,\n')
    f.write('        "f1": f1,\n')
    f.write('        "precision": precision,\n')
    f.write('        "recall": recall\n')
    f.write('    }\n\n')

    f.write('print("\\n⚙️ Configurando treinamento com 5 épocas...")\n')
    f.write('training_args = TrainingArguments(\n')
    f.write('    output_dir=OUTPUT_DIR,\n')
    f.write('    num_train_epochs=NUM_EPOCHS,\n')
    f.write('    per_device_train_batch_size=BATCH_SIZE,\n')
    f.write('    per_device_eval_batch_size=32,\n')
    f.write('    learning_rate=2e-5,\n')
    f.write('    warmup_steps=500,\n')
    f.write('    weight_decay=0.01,\n')
    f.write('    logging_dir="./logs",\n')
    f.write('    logging_steps=50,\n')
    f.write('    eval_strategy="epoch",\n')
    f.write('    save_strategy="epoch",\n')
    f.write('    load_best_model_at_end=True,\n')
    f.write('    metric_for_best_model="f1",\n')
    f.write('    save_total_limit=2,\n')
    f.write('    report_to="none",\n')
    f.write('    fp16=torch.cuda.is_available(),\n')
    f.write(')\n\n')

    f.write('trainer = Trainer(\n')
    f.write('    model=model,\n')
    f.write('    args=training_args,\n')
    f.write('    train_dataset=tokenized_datasets["train"],\n')
    f.write('    eval_dataset=tokenized_datasets["validation"],\n')
    f.write('    tokenizer=tokenizer,\n')
    f.write('    compute_metrics=compute_metrics,\n')
    f.write(')\n\n')

    f.write('print("\\n🚀 Iniciando treinamento com 5 épocas...")\n')
    f.write('print("⏱️ Estimativa com GPU: ~12-20 minutos\\n")\n\n')

    f.write('train_result = trainer.train()\n\n')

    f.write('print("\\n📊 Avaliando no conjunto de teste...")\n')
    f.write('test_results = trainer.evaluate(tokenized_datasets["test"])\n')
    f.write('print(f"\\n✅ Métricas no teste:")\n')
    f.write('print(f"   Accuracy:  {test_results[\'eval_accuracy\']:.4f}")\n')
    f.write('print(f"   F1-Score:  {test_results[\'eval_f1\']:.4f}")\n')
    f.write('print(f"   Precision: {test_results[\'eval_precision\']:.4f}")\n')
    f.write('print(f"   Recall:    {test_results[\'eval_recall\']:.4f}")\n\n')

    f.write('# Salvar modelo\n')
    f.write('print(f"\\n💾 Salvando modelo em {OUTPUT_DIR}...")\n')
    f.write('trainer.save_model(OUTPUT_DIR)\n')
    f.write('tokenizer.save_pretrained(OUTPUT_DIR)\n\n')

    f.write('# ========================================\n')
    f.write('# GERAR GRÁFICOS DE APRENDIZAGEM\n')
    f.write('# ========================================\n\n')

    f.write('print("\\n📈 Gerando gráficos de aprendizagem...")\n\n')

    f.write('# Extrair histórico de treinamento\n')
    f.write('history = trainer.state.log_history\n\n')

    f.write('# Separar métricas de treino e validação\n')
    f.write('train_loss = []\n')
    f.write('eval_loss = []\n')
    f.write('eval_accuracy = []\n')
    f.write('eval_f1 = []\n')
    f.write('eval_precision = []\n')
    f.write('eval_recall = []\n')
    f.write('epochs = []\n\n')

    f.write('for entry in history:\n')
    f.write('    if "loss" in entry and "epoch" in entry:\n')
    f.write('        train_loss.append(entry["loss"])\n')
    f.write('    if "eval_loss" in entry:\n')
    f.write('        eval_loss.append(entry["eval_loss"])\n')
    f.write('        eval_accuracy.append(entry["eval_accuracy"])\n')
    f.write('        eval_f1.append(entry["eval_f1"])\n')
    f.write('        eval_precision.append(entry["eval_precision"])\n')
    f.write('        eval_recall.append(entry["eval_recall"])\n')
    f.write('        epochs.append(entry["epoch"])\n\n')

    f.write('# Criar diretório para gráficos\n')
    f.write('os.makedirs("./graphs", exist_ok=True)\n\n')

    f.write('# Configurar estilo dos gráficos\n')
    f.write('plt.style.use("seaborn-v0_8-darkgrid")\n')
    f.write('sns.set_palette("husl")\n\n')

    f.write('# GRÁFICO 1: Loss durante o treinamento\n')
    f.write('fig, ax = plt.subplots(figsize=(10, 6))\n')
    f.write('if eval_loss:\n')
    f.write('    ax.plot(epochs, eval_loss, marker="o", linewidth=2, markersize=8, label="Validation Loss")\n')
    f.write('ax.set_xlabel("Época", fontsize=12, fontweight="bold")\n')
    f.write('ax.set_ylabel("Loss", fontsize=12, fontweight="bold")\n')
    f.write('ax.set_title("Perda durante o Treinamento (5 Épocas)", fontsize=14, fontweight="bold")\n')
    f.write('ax.legend(fontsize=10)\n')
    f.write('ax.grid(True, alpha=0.3)\n')
    f.write('plt.tight_layout()\n')
    f.write('plt.savefig("./graphs/loss_curve.png", dpi=300, bbox_inches="tight")\n')
    f.write('plt.show()\n')
    f.write('print("✅ Gráfico exibido e salvo: ./graphs/loss_curve.png")\n\n')

    f.write('# GRÁFICO 2: Accuracy\n')
    f.write('fig, ax = plt.subplots(figsize=(10, 6))\n')
    f.write('ax.plot(epochs, eval_accuracy, marker="o", linewidth=2, markersize=8, color="green", label="Validation Accuracy")\n')
    f.write('ax.set_xlabel("Época", fontsize=12, fontweight="bold")\n')
    f.write('ax.set_ylabel("Accuracy", fontsize=12, fontweight="bold")\n')
    f.write('ax.set_title("Acurácia durante o Treinamento (5 Épocas)", fontsize=14, fontweight="bold")\n')
    f.write('ax.set_ylim([0, 1])\n')
    f.write('ax.legend(fontsize=10)\n')
    f.write('ax.grid(True, alpha=0.3)\n')
    f.write('plt.tight_layout()\n')
    f.write('plt.savefig("./graphs/accuracy_curve.png", dpi=300, bbox_inches="tight")\n')
    f.write('plt.show()\n')
    f.write('print("✅ Gráfico exibido e salvo: ./graphs/accuracy_curve.png")\n\n')

    f.write('# GRÁFICO 3: F1, Precision e Recall\n')
    f.write('fig, ax = plt.subplots(figsize=(12, 6))\n')
    f.write('ax.plot(epochs, eval_f1, marker="o", linewidth=2, markersize=8, label="F1-Score")\n')
    f.write('ax.plot(epochs, eval_precision, marker="s", linewidth=2, markersize=8, label="Precision")\n')
    f.write('ax.plot(epochs, eval_recall, marker="^", linewidth=2, markersize=8, label="Recall")\n')
    f.write('ax.set_xlabel("Época", fontsize=12, fontweight="bold")\n')
    f.write('ax.set_ylabel("Score", fontsize=12, fontweight="bold")\n')
    f.write('ax.set_title("Métricas de Desempenho (5 Épocas)", fontsize=14, fontweight="bold")\n')
    f.write('ax.set_ylim([0, 1])\n')
    f.write('ax.legend(fontsize=10)\n')
    f.write('ax.grid(True, alpha=0.3)\n')
    f.write('plt.tight_layout()\n')
    f.write('plt.savefig("./graphs/metrics_curve.png", dpi=300, bbox_inches="tight")\n')
    f.write('plt.show()\n')
    f.write('print("✅ Gráfico exibido e salvo: ./graphs/metrics_curve.png")\n\n')

    f.write('# GRÁFICO 4: Matriz de Confusão\n')
    f.write('print("\\n📊 Gerando matriz de confusão...")\n')
    f.write('predictions = trainer.predict(tokenized_datasets["test"])\n')
    f.write('y_pred = np.argmax(predictions.predictions, axis=-1)\n')
    f.write('y_true = predictions.label_ids\n')
    f.write('cm = confusion_matrix(y_true, y_pred)\n\n')

    f.write('fig, ax = plt.subplots(figsize=(8, 6))\n')
    f.write('sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=True, \n')
    f.write('            xticklabels=["No Hate", "Hate"], \n')
    f.write('            yticklabels=["No Hate", "Hate"],\n')
    f.write('            annot_kws={"size": 16, "weight": "bold"})\n')
    f.write('ax.set_xlabel("Predição", fontsize=12, fontweight="bold")\n')
    f.write('ax.set_ylabel("Real", fontsize=12, fontweight="bold")\n')
    f.write('ax.set_title("Matriz de Confusão - Conjunto de Teste", fontsize=14, fontweight="bold")\n')
    f.write('plt.tight_layout()\n')
    f.write('plt.savefig("./graphs/confusion_matrix.png", dpi=300, bbox_inches="tight")\n')
    f.write('plt.show()\n')
    f.write('print("✅ Gráfico exibido e salvo: ./graphs/confusion_matrix.png")\n\n')

    f.write('# GRÁFICO 5: Resumo final (dashboard)\n')
    f.write('fig = plt.figure(figsize=(16, 10))\n')
    f.write('gs = fig.add_gridspec(2, 2, hspace=0.3, wspace=0.3)\n\n')

    f.write('# Loss\n')
    f.write('ax1 = fig.add_subplot(gs[0, 0])\n')
    f.write('ax1.plot(epochs, eval_loss, marker="o", linewidth=2, markersize=6, color="red")\n')
    f.write('ax1.set_title("Loss", fontweight="bold")\n')
    f.write('ax1.set_xlabel("Época")\n')
    f.write('ax1.set_ylabel("Loss")\n')
    f.write('ax1.grid(True, alpha=0.3)\n\n')

    f.write('# Accuracy\n')
    f.write('ax2 = fig.add_subplot(gs[0, 1])\n')
    f.write('ax2.plot(epochs, eval_accuracy, marker="o", linewidth=2, markersize=6, color="green")\n')
    f.write('ax2.set_title("Accuracy", fontweight="bold")\n')
    f.write('ax2.set_xlabel("Época")\n')
    f.write('ax2.set_ylabel("Accuracy")\n')
    f.write('ax2.set_ylim([0, 1])\n')
    f.write('ax2.grid(True, alpha=0.3)\n\n')

    f.write('# F1, Precision, Recall\n')
    f.write('ax3 = fig.add_subplot(gs[1, 0])\n')
    f.write('ax3.plot(epochs, eval_f1, marker="o", linewidth=2, label="F1")\n')
    f.write('ax3.plot(epochs, eval_precision, marker="s", linewidth=2, label="Precision")\n')
    f.write('ax3.plot(epochs, eval_recall, marker="^", linewidth=2, label="Recall")\n')
    f.write('ax3.set_title("Métricas Detalhadas", fontweight="bold")\n')
    f.write('ax3.set_xlabel("Época")\n')
    f.write('ax3.set_ylabel("Score")\n')
    f.write('ax3.set_ylim([0, 1])\n')
    f.write('ax3.legend()\n')
    f.write('ax3.grid(True, alpha=0.3)\n\n')

    f.write('# Confusion Matrix\n')
    f.write('ax4 = fig.add_subplot(gs[1, 1])\n')
    f.write('sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False, ax=ax4,\n')
    f.write('            xticklabels=["No Hate", "Hate"], \n')
    f.write('            yticklabels=["No Hate", "Hate"])\n')
    f.write('ax4.set_title("Matriz de Confusão", fontweight="bold")\n')
    f.write('ax4.set_xlabel("Predição")\n')
    f.write('ax4.set_ylabel("Real")\n\n')

    f.write('plt.suptitle("Dashboard de Treinamento - HateBERT (5 Épocas)", \n')
    f.write('             fontsize=16, fontweight="bold", y=0.995)\n')
    f.write('plt.savefig("./graphs/training_dashboard.png", dpi=300, bbox_inches="tight")\n')
    f.write('plt.show()\n')
    f.write('print("✅ Gráfico exibido e salvo: ./graphs/training_dashboard.png")\n\n')

    f.write('# Salvar métricas em JSON\n')
    f.write('metrics_summary = {\n')
    f.write('    "num_epochs": NUM_EPOCHS,\n')
    f.write('    "final_metrics": {\n')
    f.write('        "accuracy": float(test_results["eval_accuracy"]),\n')
    f.write('        "f1": float(test_results["eval_f1"]),\n')
    f.write('        "precision": float(test_results["eval_precision"]),\n')
    f.write('        "recall": float(test_results["eval_recall"])\n')
    f.write('    },\n')
    f.write('    "training_history": {\n')
    f.write('        "epochs": epochs,\n')
    f.write('        "eval_loss": eval_loss,\n')
    f.write('        "eval_accuracy": eval_accuracy,\n')
    f.write('        "eval_f1": eval_f1,\n')
    f.write('        "eval_precision": eval_precision,\n')
    f.write('        "eval_recall": eval_recall\n')
    f.write('    }\n')
    f.write('}\n\n')

    f.write('with open("./graphs/metrics_summary.json", "w") as f:\n')
    f.write('    json.dump(metrics_summary, f, indent=2)\n')
    f.write('print("✅ Métricas salvas: ./graphs/metrics_summary.json")\n\n')

    f.write('print("\\n" + "="*60)\n')
    f.write('print("✅ TREINAMENTO CONCLUÍDO!")\n')
    f.write('print("="*60)\n')
    f.write('print(f"📁 Modelo salvo em: {OUTPUT_DIR}")\n')
    f.write('print(f"📊 Gráficos salvos em: ./graphs/")\n')
    f.write('print("\\n📈 Gráficos gerados:")\n')
    f.write('print("   • loss_curve.png - Curva de perda")\n')
    f.write('print("   • accuracy_curve.png - Curva de acurácia")\n')
    f.write('print("   • metrics_curve.png - F1, Precision e Recall")\n')
    f.write('print("   • confusion_matrix.png - Matriz de confusão")\n')
    f.write('print("   • training_dashboard.png - Dashboard completo")\n')
    f.write('print("   • metrics_summary.json - Resumo das métricas")\n')
    f.write('print("="*60)\n')

print("✅ Script criado: train_5epochs_graphs.py")
print("\n🚀 Iniciando treinamento com 5 épocas...")
print("⏱️ Tempo estimado com GPU: ~12-20 minutos")
print("📊 Gráficos serão gerados automaticamente ao final")
print("=" * 60)

# !python train_5epochs_graphs.py
# Out:
# /content/HateBERT_Project/osfstorage
# 📦 Instalando dependências...
#
# ⚙️ Criando script de treinamento com 5 épocas e gráficos...
# ✅ Script criado: train_5epochs_graphs.py
#
# 🚀 Iniciando treinamento com 5 épocas...
# ⏱️ Tempo estimado com GPU: ~12-20 minutos
# 📊 Gráficos serão gerados automaticamente ao final
# ============================================================
# 2025-12-02 22:04:35.603021: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764713075.623150    1283 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764713075.629168    1283 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764713075.644049    1283 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764713075.644076    1283 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764713075.644080    1283 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764713075.644085    1283 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-02 22:04:35.648484: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🔧 Configurando treinamento HateBERT com 5 épocas...
# 💻 Usando: cuda
#
# 📥 Carregando HateBERT...
# tokenizer_config.json: 100% 151/151 [00:00<00:00, 1.28MB/s]
# config.json: 1.24kB [00:00, 6.39MB/s]
# vocab.txt: 232kB [00:00, 20.4MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 1.25MB/s]
# model.safetensors: 100% 440M/440M [00:03<00:00, 135MB/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at GroNLP/hateBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#
# 📊 Carregando dataset de hate speech (tweet_eval)...
# README.md: 23.9kB [00:00, 71.1MB/s]
# hate/train-00000-of-00001.parquet: 100% 816k/816k [00:00<00:00, 2.35MB/s]
# hate/test-00000-of-00001.parquet: 100% 278k/278k [00:00<00:00, 699kB/s]
# hate/validation-00000-of-00001.parquet: 100% 103k/103k [00:00<00:00, 113kB/s]
# Generating train split: 100% 9000/9000 [00:00<00:00, 243187.22 examples/s]
# Generating test split: 100% 2970/2970 [00:00<00:00, 703909.30 examples/s]
# Generating validation split: 100% 1000/1000 [00:00<00:00, 452167.31 examples/s]
# Dados de treino: 9000 exemplos
# Dados de validação: 1000 exemplos
# Dados de teste: 2970 exemplos
#
# 🔄 Tokenizando dados...
# Map: 100% 9000/9000 [00:01<00:00, 6439.18 examples/s]
# Map: 100% 2970/2970 [00:00<00:00, 6166.93 examples/s]
# Map: 100% 1000/1000 [00:00<00:00, 6180.26 examples/s]
#
# ⚙️ Configurando treinamento com 5 épocas...
# /content/HateBERT_Project/osfstorage/train_5epochs_graphs.py:70: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#
# 🚀 Iniciando treinamento com 5 épocas...
# ⏱️ Estimativa com GPU: ~12-20 minutos
#
# {'loss': 0.6964, 'grad_norm': 3.39799165725708, 'learning_rate': 1.9600000000000003e-06, 'epoch': 0.09}
# {'loss': 0.6691, 'grad_norm': 4.725989818572998, 'learning_rate': 3.96e-06, 'epoch': 0.18}
# {'loss': 0.6671, 'grad_norm': 2.773604154586792, 'learning_rate': 5.9600000000000005e-06, 'epoch': 0.27}
# {'loss': 0.6235, 'grad_norm': 4.444008827209473, 'learning_rate': 7.960000000000002e-06, 'epoch': 0.36}
# {'loss': 0.5656, 'grad_norm': 4.4270405769348145, 'learning_rate': 9.960000000000001e-06, 'epoch': 0.44}
# {'loss': 0.5253, 'grad_norm': 8.185044288635254, 'learning_rate': 1.196e-05, 'epoch': 0.53}
# {'loss': 0.5114, 'grad_norm': 8.539196968078613, 'learning_rate': 1.396e-05, 'epoch': 0.62}
# {'loss': 0.4511, 'grad_norm': 9.878260612487793, 'learning_rate': 1.5960000000000003e-05, 'epoch': 0.71}
# {'loss': 0.4418, 'grad_norm': 7.407422065734863, 'learning_rate': 1.796e-05, 'epoch': 0.8}
# {'loss': 0.4305, 'grad_norm': 13.647300720214844, 'learning_rate': 1.9960000000000002e-05, 'epoch': 0.89}
# {'loss': 0.4365, 'grad_norm': 11.35283088684082, 'learning_rate': 1.9576673866090716e-05, 'epoch': 0.98}
#  20% 563/2815 [01:04<04:05,  9.17it/s]
#   0% 0/32 [00:00<?, ?it/s]
#   9% 3/32 [00:00<00:00, 29.60it/s]
#  19% 6/32 [00:00<00:01, 22.38it/s]
#  28% 9/32 [00:00<00:01, 20.62it/s]
#  38% 12/32 [00:00<00:01, 19.78it/s]
#  47% 15/32 [00:00<00:00, 18.48it/s]
#  53% 17/32 [00:00<00:00, 18.18it/s]
#  59% 19/32 [00:00<00:00, 17.77it/s]
#  66% 21/32 [00:01<00:00, 17.56it/s]
#  72% 23/32 [00:01<00:00, 17.41it/s]
#  78% 25/32 [00:01<00:00, 17.41it/s]
#  84% 27/32 [00:01<00:00, 17.17it/s]
#  91% 29/32 [00:01<00:00, 17.05it/s]
#
# {'eval_loss': 0.505092203617096, 'eval_accuracy': 0.746, 'eval_f1': 0.7221006564551422, 'eval_precision': 0.6776180698151951, 'eval_recall': 0.7728337236533958, 'eval_runtime': 1.8055, 'eval_samples_per_second': 553.873, 'eval_steps_per_second': 17.724, 'epoch': 1.0}
#  20% 563/2815 [01:06<04:05,  9.17it/s]
# 100% 32/32 [00:01<00:00, 17.57it/s]
# {'loss': 0.3921, 'grad_norm': 4.441198348999023, 'learning_rate': 1.9144708423326134e-05, 'epoch': 1.07}
# {'loss': 0.3495, 'grad_norm': 7.280458927154541, 'learning_rate': 1.8712742980561555e-05, 'epoch': 1.15}
# {'loss': 0.3727, 'grad_norm': 7.829041004180908, 'learning_rate': 1.828077753779698e-05, 'epoch': 1.24}
# {'loss': 0.3116, 'grad_norm': 7.348353862762451, 'learning_rate': 1.78488120950324e-05, 'epoch': 1.33}
# {'loss': 0.3375, 'grad_norm': 9.150177955627441, 'learning_rate': 1.741684665226782e-05, 'epoch': 1.42}
# {'loss': 0.3199, 'grad_norm': 6.718921184539795, 'learning_rate': 1.698488120950324e-05, 'epoch': 1.51}
# {'loss': 0.3556, 'grad_norm': 8.265817642211914, 'learning_rate': 1.6552915766738662e-05, 'epoch': 1.6}
# {'loss': 0.3565, 'grad_norm': 9.531359672546387, 'learning_rate': 1.6120950323974083e-05, 'epoch': 1.69}
# {'loss': 0.335, 'grad_norm': 5.656510829925537, 'learning_rate': 1.5688984881209505e-05, 'epoch': 1.78}
# {'loss': 0.3467, 'grad_norm': 9.28073501586914, 'learning_rate': 1.5257019438444926e-05, 'epoch': 1.87}
# {'loss': 0.3453, 'grad_norm': 7.854807376861572, 'learning_rate': 1.4825053995680348e-05, 'epoch': 1.95}
#  40% 1125/2815 [02:19<03:22,  8.33it/s]
#   0% 0/32 [00:00<?, ?it/s]
#   9% 3/32 [00:00<00:01, 26.12it/s]
#  19% 6/32 [00:00<00:01, 20.83it/s]
#  28% 9/32 [00:00<00:01, 19.68it/s]
#  38% 12/32 [00:00<00:01, 19.06it/s]
#  44% 14/32 [00:00<00:00, 18.72it/s]
#  50% 16/32 [00:00<00:00, 18.58it/s]
#  56% 18/32 [00:00<00:00, 18.62it/s]
#  62% 20/32 [00:01<00:00, 18.58it/s]
#  69% 22/32 [00:01<00:00, 18.57it/s]
#  75% 24/32 [00:01<00:00, 18.59it/s]
#  81% 26/32 [00:01<00:00, 18.47it/s]
#  88% 28/32 [00:01<00:00, 18.54it/s]
#
# {'eval_loss': 0.5024796724319458, 'eval_accuracy': 0.776, 'eval_f1': 0.7559912854030502, 'eval_precision': 0.7067209775967414, 'eval_recall': 0.8126463700234192, 'eval_runtime': 1.7311, 'eval_samples_per_second': 577.679, 'eval_steps_per_second': 18.486, 'epoch': 2.0}
#  40% 1126/2815 [02:21<03:22,  8.33it/s]
# 100% 32/32 [00:01<00:00, 18.56it/s]
# {'loss': 0.2968, 'grad_norm': 2.283881187438965, 'learning_rate': 1.4393088552915767e-05, 'epoch': 2.04}
# {'loss': 0.1859, 'grad_norm': 11.17004680633545, 'learning_rate': 1.3961123110151189e-05, 'epoch': 2.13}
# {'loss': 0.2208, 'grad_norm': 13.79824161529541, 'learning_rate': 1.352915766738661e-05, 'epoch': 2.22}
# {'loss': 0.2549, 'grad_norm': 13.606217384338379, 'learning_rate': 1.309719222462203e-05, 'epoch': 2.31}
# {'loss': 0.1953, 'grad_norm': 15.5941801071167, 'learning_rate': 1.2665226781857451e-05, 'epoch': 2.4}
# {'loss': 0.1952, 'grad_norm': 3.055602550506592, 'learning_rate': 1.2233261339092875e-05, 'epoch': 2.49}
# {'loss': 0.1967, 'grad_norm': 9.88088607788086, 'learning_rate': 1.1801295896328296e-05, 'epoch': 2.58}
# {'loss': 0.224, 'grad_norm': 13.437994956970215, 'learning_rate': 1.1369330453563716e-05, 'epoch': 2.66}
# {'loss': 0.1907, 'grad_norm': 4.660577297210693, 'learning_rate': 1.0937365010799137e-05, 'epoch': 2.75}
# {'loss': 0.208, 'grad_norm': 10.196152687072754, 'learning_rate': 1.0505399568034558e-05, 'epoch': 2.84}
# {'loss': 0.174, 'grad_norm': 20.961801528930664, 'learning_rate': 1.0073434125269978e-05, 'epoch': 2.93}
#  60% 1688/2815 [03:40<02:10,  8.64it/s]
#   0% 0/32 [00:00<?, ?it/s]
#   9% 3/32 [00:00<00:01, 27.97it/s]
#  19% 6/32 [00:00<00:01, 21.25it/s]
#  28% 9/32 [00:00<00:01, 19.81it/s]
#  38% 12/32 [00:00<00:01, 18.99it/s]
#  44% 14/32 [00:00<00:00, 18.74it/s]
#  50% 16/32 [00:00<00:00, 18.24it/s]
#  56% 18/32 [00:00<00:00, 17.69it/s]
#  62% 20/32 [00:01<00:00, 17.44it/s]
#  69% 22/32 [00:01<00:00, 17.14it/s]
#  75% 24/32 [00:01<00:00, 16.93it/s]
#  81% 26/32 [00:01<00:00, 16.80it/s]
#  88% 28/32 [00:01<00:00, 16.73it/s]
#
# {'eval_loss': 0.676787257194519, 'eval_accuracy': 0.788, 'eval_f1': 0.7749469214437368, 'eval_precision': 0.7087378640776699, 'eval_recall': 0.8548009367681498, 'eval_runtime': 1.8287, 'eval_samples_per_second': 546.838, 'eval_steps_per_second': 17.499, 'epoch': 3.0}
#  60% 1689/2815 [03:42<02:10,  8.64it/s]
# 100% 32/32 [00:01<00:00, 16.49it/s]
# {'loss': 0.1637, 'grad_norm': 0.8873540759086609, 'learning_rate': 9.641468682505401e-06, 'epoch': 3.02}
# {'loss': 0.1185, 'grad_norm': 3.2144243717193604, 'learning_rate': 9.209503239740821e-06, 'epoch': 3.11}
# {'loss': 0.0944, 'grad_norm': 0.143036887049675, 'learning_rate': 8.777537796976242e-06, 'epoch': 3.2}
# {'loss': 0.1226, 'grad_norm': 0.8911997079849243, 'learning_rate': 8.345572354211664e-06, 'epoch': 3.29}
# {'loss': 0.0874, 'grad_norm': 5.737055778503418, 'learning_rate': 7.913606911447085e-06, 'epoch': 3.37}
# {'loss': 0.1172, 'grad_norm': 36.67812728881836, 'learning_rate': 7.481641468682506e-06, 'epoch': 3.46}
# {'loss': 0.1829, 'grad_norm': 48.39952087402344, 'learning_rate': 7.049676025917927e-06, 'epoch': 3.55}
# {'loss': 0.0953, 'grad_norm': 0.11653365939855576, 'learning_rate': 6.617710583153349e-06, 'epoch': 3.64}
# {'loss': 0.0885, 'grad_norm': 17.781940460205078, 'learning_rate': 6.185745140388769e-06, 'epoch': 3.73}
# {'loss': 0.116, 'grad_norm': 0.21992063522338867, 'learning_rate': 5.753779697624191e-06, 'epoch': 3.82}
# {'loss': 0.0791, 'grad_norm': 0.1453639417886734, 'learning_rate': 5.321814254859612e-06, 'epoch': 3.91}
# {'loss': 0.1016, 'grad_norm': 7.1003642082214355, 'learning_rate': 4.889848812095033e-06, 'epoch': 4.0}
#  80% 2251/2815 [05:03<01:06,  8.54it/s]
#   0% 0/32 [00:00<?, ?it/s]
#   9% 3/32 [00:00<00:01, 26.61it/s]
#  19% 6/32 [00:00<00:01, 20.73it/s]
#  28% 9/32 [00:00<00:01, 19.41it/s]
#  34% 11/32 [00:00<00:01, 18.99it/s]
#  41% 13/32 [00:00<00:01, 18.35it/s]
#  47% 15/32 [00:00<00:00, 18.31it/s]
#  53% 17/32 [00:00<00:00, 18.03it/s]
#  59% 19/32 [00:01<00:00, 18.16it/s]
#  66% 21/32 [00:01<00:00, 18.07it/s]
#  72% 23/32 [00:01<00:00, 18.09it/s]
#  78% 25/32 [00:01<00:00, 18.00it/s]
#  84% 27/32 [00:01<00:00, 18.03it/s]
#  91% 29/32 [00:01<00:00, 17.81it/s]
#
# {'eval_loss': 0.9368256330490112, 'eval_accuracy': 0.786, 'eval_f1': 0.7606263982102909, 'eval_precision': 0.728051391862955, 'eval_recall': 0.7962529274004684, 'eval_runtime': 1.7763, 'eval_samples_per_second': 562.959, 'eval_steps_per_second': 18.015, 'epoch': 4.0}
#  80% 2252/2815 [05:05<01:05,  8.54it/s]
# 100% 32/32 [00:01<00:00, 17.81it/s]
# {'loss': 0.0539, 'grad_norm': 4.870203018188477, 'learning_rate': 4.457883369330454e-06, 'epoch': 4.09}
# {'loss': 0.0375, 'grad_norm': 31.761140823364258, 'learning_rate': 4.025917926565875e-06, 'epoch': 4.17}
# {'loss': 0.0757, 'grad_norm': 1.0851707458496094, 'learning_rate': 3.593952483801296e-06, 'epoch': 4.26}
# {'loss': 0.0405, 'grad_norm': 2.347287654876709, 'learning_rate': 3.161987041036717e-06, 'epoch': 4.35}
# {'loss': 0.0963, 'grad_norm': 55.824317932128906, 'learning_rate': 2.7300215982721385e-06, 'epoch': 4.44}
# {'loss': 0.0455, 'grad_norm': 37.20326614379883, 'learning_rate': 2.2980561555075595e-06, 'epoch': 4.53}
# {'loss': 0.0615, 'grad_norm': 0.6194784045219421, 'learning_rate': 1.8660907127429807e-06, 'epoch': 4.62}
# {'loss': 0.082, 'grad_norm': 3.5035793781280518, 'learning_rate': 1.4341252699784019e-06, 'epoch': 4.71}
# {'loss': 0.0679, 'grad_norm': 64.39813995361328, 'learning_rate': 1.002159827213823e-06, 'epoch': 4.8}
# {'loss': 0.0407, 'grad_norm': 0.06702066957950592, 'learning_rate': 5.701943844492442e-07, 'epoch': 4.88}
# {'loss': 0.0978, 'grad_norm': 10.483710289001465, 'learning_rate': 1.3822894168466524e-07, 'epoch': 4.97}
# 100% 2814/2815 [07:16<00:00,  8.36it/s]
#   0% 0/32 [00:00<?, ?it/s]
#   9% 3/32 [00:00<00:01, 26.90it/s]
#  19% 6/32 [00:00<00:01, 21.13it/s]
#  28% 9/32 [00:00<00:01, 19.75it/s]
#  38% 12/32 [00:00<00:01, 18.89it/s]
#  44% 14/32 [00:00<00:00, 18.63it/s]
#  50% 16/32 [00:00<00:00, 18.56it/s]
#  56% 18/32 [00:00<00:00, 18.40it/s]
#  62% 20/32 [00:01<00:00, 18.42it/s]
#  69% 22/32 [00:01<00:00, 18.16it/s]
#  75% 24/32 [00:01<00:00, 18.29it/s]
#  81% 26/32 [00:01<00:00, 18.16it/s]
#  88% 28/32 [00:01<00:00, 18.16it/s]
#
# {'eval_loss': 1.0518994331359863, 'eval_accuracy': 0.778, 'eval_f1': 0.754424778761062, 'eval_precision': 0.7148846960167715, 'eval_recall': 0.7985948477751756, 'eval_runtime': 1.7437, 'eval_samples_per_second': 573.479, 'eval_steps_per_second': 18.351, 'epoch': 5.0}
# 100% 2815/2815 [07:18<00:00,  8.36it/s]
# 100% 32/32 [00:01<00:00, 18.13it/s]
# {'train_runtime': 500.0546, 'train_samples_per_second': 89.99, 'train_steps_per_second': 5.629, 'train_loss': 0.2532581953871102, 'epoch': 5.0}
# 100% 2815/2815 [08:20<00:00,  5.63it/s]
#
# 📊 Avaliando no conjunto de teste...
# 100% 93/93 [00:05<00:00, 17.94it/s]
#
# ✅ Métricas no teste:
#    Accuracy:  0.5374
#    F1-Score:  0.6392
#    Precision: 0.4761
#    Recall:    0.9720
#
# 💾 Salvando modelo em ./hatebert_5epochs...
#
# 📈 Gerando gráficos de aprendizagem...
# Figure(1000x600)
# ✅ Gráfico exibido e salvo: ./graphs/loss_curve.png
# Figure(1000x600)
# ✅ Gráfico exibido e salvo: ./graphs/accuracy_curve.png
# Figure(1200x600)
# ✅ Gráfico exibido e salvo: ./graphs/metrics_curve.png
#
# 📊 Gerando matriz de confusão...
# 100% 93/93 [00:04<00:00, 18.97it/s]
# Figure(800x600)
# ✅ Gráfico exibido e salvo: ./graphs/confusion_matrix.png
# Figure(1600x1000)
# ✅ Gráfico exibido e salvo: ./graphs/training_dashboard.png
# ✅ Métricas salvas: ./graphs/metrics_summary.json
#
# ============================================================
# ✅ TREINAMENTO CONCLUÍDO!
# ============================================================
# 📁 Modelo salvo em: ./hatebert_5epochs
# 📊 Gráficos salvos em: ./graphs/
#
# 📈 Gráficos gerados:
#    • loss_curve.png - Curva de perda
#    • accuracy_curve.png - Curva de acurácia
#    • metrics_curve.png - F1, Precision e Recall
#    • confusion_matrix.png - Matriz de confusão
#    • training_dashboard.png - Dashboard completo
#    • metrics_summary.json - Resumo das métricas
# ============================================================

# %%
# ========================================
# SALVAR APENAS OS GRÁFICOS NO GOOGLE DRIVE
# ========================================

print("📤 Conectando ao Google Drive...")
from google.colab import drive
drive.mount('/content/drive')

print("\n📁 Criando pasta no Drive para os gráficos...")
import os
import shutil
from datetime import datetime

# Criar pasta com data atual
data_atual = datetime.now().strftime("%Y-%m-%d")
drive_folder = f"/content/drive/MyDrive/HateBERT_Graphs_{data_atual}"

# Criar pasta se não existir
os.makedirs(drive_folder, exist_ok=True)
print(f"📂 Pasta: {drive_folder}")

# Caminho dos gráficos gerados
graphics_source = "/content/HateBERT_Project/osfstorage/graphs"

# Verificar se os gráficos existem
if os.path.exists(graphics_source):
    print(f"\n📊 Encontrei {len(os.listdir(graphics_source))} arquivos na pasta de gráficos:")

    # Listar todos os arquivos de gráficos
    graphics_files = os.listdir(graphics_source)

    # Copiar cada arquivo de gráfico
    for file in graphics_files:
        if file.endswith(('.png', '.jpg', '.jpeg', '.json')):
            source_file = os.path.join(graphics_source, file)
            dest_file = os.path.join(drive_folder, file)

            shutil.copy2(source_file, dest_file)
            print(f"✅ Copiado: {file}")

    print(f"\n🎯 Total de {len([f for f in graphics_files if f.endswith('.png')])} gráficos PNG salvos")
    print(f"📈 Total de {len([f for f in graphics_files if f.endswith('.json')])} arquivos JSON salvos")

else:
    print(f"❌ Pasta de gráficos não encontrada: {graphics_source}")
    print("Execute o treinamento primeiro para gerar os gráficos!")

# Mostrar o que foi salvo
print("\n📋 Gráficos salvos no Drive:")
if os.path.exists(drive_folder):
    for file in os.listdir(drive_folder):
        if file.endswith('.png'):
            print(f"   📊 {file}")

print("\n✅ PRONTO! Gráficos salvos no Google Drive.")
# Out:
# 📤 Conectando ao Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# 📁 Criando pasta no Drive para os gráficos...
# 📂 Pasta: /content/drive/MyDrive/HateBERT_Graphs_2025-12-02
#
# 📊 Encontrei 6 arquivos na pasta de gráficos:
# ✅ Copiado: metrics_summary.json
# ✅ Copiado: confusion_matrix.png
# ✅ Copiado: accuracy_curve.png
# ✅ Copiado: loss_curve.png
# ✅ Copiado: training_dashboard.png
# ✅ Copiado: metrics_curve.png
#
# 🎯 Total de 5 gráficos PNG salvos
# 📈 Total de 1 arquivos JSON salvos
#
# 📋 Gráficos salvos no Drive:
#    📊 confusion_matrix.png
#    📊 accuracy_curve.png
#    📊 loss_curve.png
#    📊 training_dashboard.png
#    📊 metrics_curve.png
#
# ✅ PRONTO! Gráficos salvos no Google Drive.
